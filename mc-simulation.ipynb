# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Import and Clean Data

# %%
df = pd.read_csv("data_cash_flow.csv", sep=";")
df
# Out:
#                Years Unnamed: 1               1               2
# 0       Cantidad (Q)          =             153             219  \
# 1         Precio (p)          =     $1.329.223      $1.366.262
# 2                 cv          =        $93.046         $95.638
# 3            Ingreso          +   $203.862.912    $299.347.958
# 4   Costo Venta (CV)          -    $14.270.404     $20.954.357
# 5     Utilidad Bruta          =   $189.592.508    $278.393.601
# 6       Costos fijos          -    $25.276.740     $26.540.577
# 7                 GA          -   $242.604.000    $259.586.280
# 8          Intereses          -     $1.901.798      $1.605.278
# 9       Amortización          -     $1.400.000      $1.400.000
# 10      depreciación          -     $2.157.482      $2.157.482
# 11               UAI          =   -$83.747.512    -$12.896.016
# 12         Impuesto         27%             $-              $-
# 13               UDI          =   -$83.747.512    -$12.896.016
# 14         Intereses          +     $1.901.798      $1.605.278
# 15             Cuota          -      $4.277.766      $4.277.766
# 16      Depreciación          +      $2.157.482      $2.157.482
# 17     Flujo de caja          =   -$83.965.997    -$13.411.021
#
#                  3               4               5           Unnamed: 7
# 0              285             351             416                  NaN  \
# 1      $1.404.333      $1.443.465      $1.483.687                   NaN
# 2         $98.303        $101.043        $103.858                   NaN
# 3    $399.996.111    $506.020.971    $617.644.034                   NaN
# 4     $27.999.728     $35.421.468     $43.235.082                   NaN
# 5    $371.996.383    $470.599.503    $574.408.952                   NaN
# 6     $27.867.606     $29.260.986     $30.724.035   Aumenta un 5% anual
# 7    $277.757.320    $297.200.332    $318.004.355   Aumenta un 7% anual
# 8      $1.271.751        $896.601        $474.631                   NaN
# 9      $1.400.000      $1.400.000      $1.400.000                   NaN
# 10     $2.157.482      $2.157.482      $2.157.482                   NaN
# 11    $61.542.225    $139.684.103    $221.648.448                   NaN
# 12    $16.616.401     $37.714.708     $59.845.081                   NaN
# 13    $44.925.824    $101.969.395    $161.803.367                   NaN
# 14     $1.271.751        $896.601        $474.631                   NaN
# 15      $4.277.766      $4.277.766      $4.277.766                  NaN
# 16      $2.157.482      $2.157.482      $2.157.482                  NaN
# 17    $44.077.292    $100.745.712    $160.157.714                   NaN
#
#     Unnamed: 8  Unnamed: 9  Unnamed: 10  Unnamed: 11
# 0          NaN         NaN          NaN          NaN
# 1          NaN         NaN          NaN          NaN
# 2          NaN         NaN          NaN          NaN
# 3          NaN         NaN          NaN          NaN
# 4          NaN         NaN          NaN          NaN
# 5          NaN         NaN          NaN          NaN
# 6          NaN         NaN          NaN          NaN
# 7          NaN         NaN          NaN          NaN
# 8          NaN         NaN          NaN          NaN
# 9          NaN         NaN          NaN          NaN
# 10         NaN         NaN          NaN          NaN
# 11         NaN         NaN          NaN          NaN
# 12         NaN         NaN          NaN          NaN
# 13         NaN         NaN          NaN          NaN
# 14         NaN         NaN          NaN          NaN
# 15         NaN         NaN          NaN          NaN
# 16         NaN         NaN          NaN          NaN
# 17         NaN         NaN          NaN          NaN

# %%
df.drop(columns=['Unnamed: 1','Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'], inplace=True)
df
# Out:
#                Years               1               2               3
# 0       Cantidad (Q)             153             219             285  \
# 1         Precio (p)     $1.329.223      $1.366.262      $1.404.333
# 2                 cv        $93.046         $95.638         $98.303
# 3            Ingreso   $203.862.912    $299.347.958    $399.996.111
# 4   Costo Venta (CV)    $14.270.404     $20.954.357     $27.999.728
# 5     Utilidad Bruta   $189.592.508    $278.393.601    $371.996.383
# 6       Costos fijos    $25.276.740     $26.540.577     $27.867.606
# 7                 GA   $242.604.000    $259.586.280    $277.757.320
# 8          Intereses     $1.901.798      $1.605.278      $1.271.751
# 9       Amortización     $1.400.000      $1.400.000      $1.400.000
# 10      depreciación     $2.157.482      $2.157.482      $2.157.482
# 11               UAI   -$83.747.512    -$12.896.016     $61.542.225
# 12         Impuesto              $-              $-     $16.616.401
# 13               UDI   -$83.747.512    -$12.896.016     $44.925.824
# 14         Intereses     $1.901.798      $1.605.278      $1.271.751
# 15             Cuota      $4.277.766      $4.277.766      $4.277.766
# 16      Depreciación      $2.157.482      $2.157.482      $2.157.482
# 17     Flujo de caja   -$83.965.997    -$13.411.021     $44.077.292
#
#                  4               5
# 0              351             416
# 1      $1.443.465      $1.483.687
# 2        $101.043        $103.858
# 3    $506.020.971    $617.644.034
# 4     $35.421.468     $43.235.082
# 5    $470.599.503    $574.408.952
# 6     $29.260.986     $30.724.035
# 7    $297.200.332    $318.004.355
# 8        $896.601        $474.631
# 9      $1.400.000      $1.400.000
# 10     $2.157.482      $2.157.482
# 11   $139.684.103    $221.648.448
# 12    $37.714.708     $59.845.081
# 13   $101.969.395    $161.803.367
# 14       $896.601        $474.631
# 15      $4.277.766      $4.277.766
# 16      $2.157.482      $2.157.482
# 17   $100.745.712    $160.157.714

# %%
df["1"] = [e.replace(".","").replace("$","").replace(" ","") for i,e in enumerate(df["1"])]
df["2"] = [e.replace(".","").replace("$","").replace(" ","") for i,e in enumerate(df["2"])]
df["3"] = [e.replace(".","").replace("$","").replace(" ","") for i,e in enumerate(df["3"])]
df["4"] = [e.replace(".","").replace("$","").replace(" ","") for i,e in enumerate(df["4"])]
df["5"] = [e.replace(".","").replace("$","").replace(" ","") for i,e in enumerate(df["5"])]
df
# Out:
#                Years          1          2          3          4          5
# 0       Cantidad (Q)        153        219        285        351        416
# 1         Precio (p)    1329223    1366262    1404333    1443465    1483687
# 2                 cv      93046      95638      98303     101043     103858
# 3            Ingreso  203862912  299347958  399996111  506020971  617644034
# 4   Costo Venta (CV)   14270404   20954357   27999728   35421468   43235082
# 5     Utilidad Bruta  189592508  278393601  371996383  470599503  574408952
# 6       Costos fijos   25276740   26540577   27867606   29260986   30724035
# 7                 GA  242604000  259586280  277757320  297200332  318004355
# 8          Intereses    1901798    1605278    1271751     896601     474631
# 9       Amortización    1400000    1400000    1400000    1400000    1400000
# 10      depreciación    2157482    2157482    2157482    2157482    2157482
# 11               UAI  -83747512  -12896016   61542225  139684103  221648448
# 12         Impuesto           -          -   16616401   37714708   59845081
# 13               UDI  -83747512  -12896016   44925824  101969395  161803367
# 14         Intereses    1901798    1605278    1271751     896601     474631
# 15             Cuota    4277766    4277766    4277766    4277766    4277766
# 16      Depreciación    2157482    2157482    2157482    2157482    2157482
# 17     Flujo de caja  -83965997  -13411021   44077292  100745712  160157714

# %%
df["1"][12] = 0
df["2"][12] = 0
df
# Out:
#                Years          1          2          3          4          5
# 0       Cantidad (Q)        153        219        285        351        416
# 1         Precio (p)    1329223    1366262    1404333    1443465    1483687
# 2                 cv      93046      95638      98303     101043     103858
# 3            Ingreso  203862912  299347958  399996111  506020971  617644034
# 4   Costo Venta (CV)   14270404   20954357   27999728   35421468   43235082
# 5     Utilidad Bruta  189592508  278393601  371996383  470599503  574408952
# 6       Costos fijos   25276740   26540577   27867606   29260986   30724035
# 7                 GA  242604000  259586280  277757320  297200332  318004355
# 8          Intereses    1901798    1605278    1271751     896601     474631
# 9       Amortización    1400000    1400000    1400000    1400000    1400000
# 10      depreciación    2157482    2157482    2157482    2157482    2157482
# 11               UAI  -83747512  -12896016   61542225  139684103  221648448
# 12         Impuesto           0          0   16616401   37714708   59845081
# 13               UDI  -83747512  -12896016   44925824  101969395  161803367
# 14         Intereses    1901798    1605278    1271751     896601     474631
# 15             Cuota    4277766    4277766    4277766    4277766    4277766
# 16      Depreciación    2157482    2157482    2157482    2157482    2157482
# 17     Flujo de caja  -83965997  -13411021   44077292  100745712  160157714

# %%
df["1"] = [int(e) for i,e in enumerate(df["1"])]
df["2"] = [int(e) for i,e in enumerate(df["2"])]
df["3"] = [int(e) for i,e in enumerate(df["3"])]
df["4"] = [int(e) for i,e in enumerate(df["4"])]
df["5"] = [int(e) for i,e in enumerate(df["5"])]
df
# Out:
#                Years          1          2          3          4          5
# 0       Cantidad (Q)        153        219        285        351        416
# 1         Precio (p)    1329223    1366262    1404333    1443465    1483687
# 2                 cv      93046      95638      98303     101043     103858
# 3            Ingreso  203862912  299347958  399996111  506020971  617644034
# 4   Costo Venta (CV)   14270404   20954357   27999728   35421468   43235082
# 5     Utilidad Bruta  189592508  278393601  371996383  470599503  574408952
# 6       Costos fijos   25276740   26540577   27867606   29260986   30724035
# 7                 GA  242604000  259586280  277757320  297200332  318004355
# 8          Intereses    1901798    1605278    1271751     896601     474631
# 9       Amortización    1400000    1400000    1400000    1400000    1400000
# 10      depreciación    2157482    2157482    2157482    2157482    2157482
# 11               UAI  -83747512  -12896016   61542225  139684103  221648448
# 12         Impuesto           0          0   16616401   37714708   59845081
# 13               UDI  -83747512  -12896016   44925824  101969395  161803367
# 14         Intereses    1901798    1605278    1271751     896601     474631
# 15             Cuota    4277766    4277766    4277766    4277766    4277766
# 16      Depreciación    2157482    2157482    2157482    2157482    2157482
# 17     Flujo de caja  -83965997  -13411021   44077292  100745712  160157714

# %% [markdown]
# ## Simulations

# %% [markdown]
# ### Price

# %%
def price():
    price = np.round(
        np.random.normal(
            loc=np.mean(df.iloc[1,1:]),
            scale=np.std(df.iloc[1,1:]),
            size=1),
        0)
    price = int(np.mean(price))
    return price
price()
# Out:
# 1387649

# %% [markdown]
# ### Fixed Costs

# %%
def fixed_costs():
    fc = int(np.round(np.random.uniform(low=df.iloc[6,1], high=df.iloc[6,5]),0))
    return fc
fixed_costs()
# Out:
# 27627660

# %% [markdown]
# ### Quantity

# %%
def quantity():
    q = np.round(
        np.random.normal(
            loc=np.mean(df.iloc[0,1:]),
            scale=np.std(df.iloc[0,1:]),
            size=1),
        0)
    q = int(np.mean(q))
    return q
quantity()
# Out:
# 328

# %% [markdown]
# ### Managment Costs

# %%
def mgmt_costs():
    mc = int(np.round(np.random.uniform(low=df.iloc[7,1], high=df.iloc[7,5]),0))
    return mc
mgmt_costs()
# Out:
# 287428738

# %% [markdown]
# ### Revenue, Sales Costs, Income

# %%
def revenue():
    revenue = quantity() * price()
    return revenue
revenue()

sales_commission = 0.07

def sales_costs():
    sc = int(revenue() * sales_commission)
    return sc

def income():
    inc = revenue() - sales_costs()
    return inc
income()
# Out:
# 365461947

# %% [markdown]
# ### Interest, Amortization, Installment

# %%
def interest():
    interest = int(np.round(np.random.uniform(low=df.iloc[8,1], high=df.iloc[8,5]),0))
    return interest

amortization = df.iloc[9,1]
depreciation = df.iloc[10,1]

# %% [markdown]
# ### Earnings Before Taxes, Taxes and Earnings After Taxes

# %%
def Earns_Bef_Tax():
    ebt = income() - ( interest() + amortization + installment + mgmt_costs())
    return ebt

def taxes():
    if (int(Earns_Bef_Tax() * 0.27)) < 0:
        return 0
    else:
        return (int(Earns_Bef_Tax() * 0.27))

def Earns_Af_Tax():
    eat = Earns_Bef_Tax() - taxes()
    return eat

installment = df.iloc[15,1]

# %% [markdown]
# ### Net Income

# %%
def net_income():
    ni = (Earns_Af_Tax() + interest() + depreciation) - installment
    return ni

net_income()
# Out:
# 19253226

# %% [markdown]
# ### Simulation

# %%
# q_sim = int(input("Please, enter number of simulations: "))

q_sim = 10000
mc_net_income = [net_income() for element in range(q_sim)]
botton_lim = 35_000_000
upper_lim = 120_000_000

mean = np.mean(mc_net_income)
std_dev = np.std(mc_net_income)

botton_Z = (botton_lim-mean)/std_dev
upper_Z = (upper_lim-mean)/std_dev

X = round(upper_Z-botton_Z,2) * 100

# %%
print(f"{X}%")
print("Mean: ${:,.2f}".format(int(mean)))
print("Std Dev: ${:,.2f}".format(int(std_dev)))
sns.histplot(mc_net_income)
plt.show()
# Out:
# 0.61%
# Mean: $68,029,066.00
# Std Dev: $139,116,790.00
